# %%
# Importamos librerías
import sklearn.datasets as datasets
import pandas as pd
import pydotplus
from sklearn.externals.six import StringIO
from IPython.display import Image
from sklearn.tree import export_graphviz
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
# Cargamos los datos
iris = datasets.load_iris()
# Definimos un Dataframe (estructura tabular) con las variables predictoras
# y por otro lado un vector apartado con la variable respuesta
df = pd.DataFrame(iris.data, columns=iris.feature_names)
y = iris.target
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
# Partir datos en train y test
X_train, X_test, y_train, y_test = train_test_split(
df, y, test_size=0.25, random_state=42)
# Crear modelo
dtree = DecisionTreeClassifier()
# Entrenar modelo
dtree.fit(X_train, y_train)
#########
# Gráfico
dot_data = StringIO()
export_graphviz(dtree, out_file=dot_data,
filled=True, rounded=True,
special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())
#########

# %%
X_train, X_test, y_train, y_test = train_test_split(
df, y, test_size=0.25, random_state=4)
dtree = DecisionTreeClassifier()
dtree.fit(X_train, y_train)
#########
# Gráfico
dot_data = StringIO()
export_graphviz(dtree, out_file=dot_data,
                filled=True, rounded=True,
                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())
#########

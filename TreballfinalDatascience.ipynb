# %%
import pandas as pd
import seaborn as sns

# %%
ds_15 = pd.read_csv('data/2015.csv')
ds_16 = pd.read_csv('data/2016.csv')
ds_17 = pd.read_csv('data/2017.csv')
ds_18 = pd.read_csv('data/2018.csv')
ds_19 = pd.read_csv('data/2019.csv')
ds_19.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
# https://towardsdatascience.com/visualizing-data-with-pair-plots-in-python-f228cf529166
sns.pairplot(ds_19.drop(columns='Country or region'))

# %%
ds_19.hist(column='Score')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2aa04f35d0>]],
#       dtype=object)

# %%
ds_19.drop(columns=['Overall rank', 'Score']).boxplot()

# %%
ds_19.boxplot('Score')
